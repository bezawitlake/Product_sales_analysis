# %%
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
data=pd.read_csv("WalmartSalesData.csv")

# %%
data.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total  \
# 0       Health and beauty       74.69         7  26.1415  548.9715
# 1  Electronic accessories       15.28         5   3.8200   80.2200
# 2      Home and lifestyle       46.33         7  16.2155  340.5255
# 3       Health and beauty       58.22         8  23.2880  489.0480
# 4       Sports and travel       86.31         7  30.2085  634.3785
#
#          Date      Time      Payment    cogs  gross margin percentage  \
# 0  2019-01-05  13:08:00      Ewallet  522.83                 4.761905
# 1  2019-03-08  10:29:00         Cash   76.40                 4.761905
# 2  2019-03-03  13:23:00  Credit card  324.31                 4.761905
# 3  2019-01-27  20:33:00      Ewallet  465.76                 4.761905
# 4  2019-02-08  10:37:00      Ewallet  604.17                 4.761905
#
#    gross income  Rating
# 0       26.1415     9.1
# 1        3.8200     9.6
# 2       16.2155     7.4
# 3       23.2880     8.4
# 4       30.2085     5.3

# %%
data.tail()
# Out:
#       Invoice ID Branch       City Customer type  Gender         Product line  \
# 995  233-67-5758      C  Naypyitaw        Normal    Male    Health and beauty
# 996  303-96-2227      B   Mandalay        Normal  Female   Home and lifestyle
# 997  727-02-1313      A     Yangon        Member    Male   Food and beverages
# 998  347-56-2442      A     Yangon        Normal    Male   Home and lifestyle
# 999  849-09-3807      A     Yangon        Member  Female  Fashion accessories
#
#      Unit price  Quantity   Tax 5%      Total        Date      Time  Payment  \
# 995       40.35         1   2.0175    42.3675  2019-01-29  13:46:00  Ewallet
# 996       97.38        10  48.6900  1022.4900  2019-03-02  17:16:00  Ewallet
# 997       31.84         1   1.5920    33.4320  2019-02-09  13:22:00     Cash
# 998       65.82         1   3.2910    69.1110  2019-02-22  15:33:00     Cash
# 999       88.34         7  30.9190   649.2990  2019-02-18  13:28:00     Cash
#
#        cogs  gross margin percentage  gross income  Rating
# 995   40.35                 4.761905        2.0175     6.2
# 996  973.80                 4.761905       48.6900     4.4
# 997   31.84                 4.761905        1.5920     7.7
# 998   65.82                 4.761905        3.2910     4.1
# 999  618.38                 4.761905       30.9190     6.6

# %%
data.shape
# Out:
# (1000, 17)

# %%
data.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
#  14  gross margin percentage  1000 non-null   float64
#  15  gross income             1000 non-null   float64
#  16  Rating                   1000 non-null   float64
# dtypes: float64(7), int64(1), object(9)
# memory usage: 132.9+ KB

# %%
data.isna().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
data.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %%
print(data.duplicated().sum())
# Out:
# 0

# %%
data.describe().round()
# Out:
#        Unit price  Quantity  Tax 5%   Total    cogs  gross margin percentage  \
# count      1000.0    1000.0  1000.0  1000.0  1000.0                   1000.0
# mean         56.0       6.0    15.0   323.0   308.0                      5.0
# std          26.0       3.0    12.0   246.0   234.0                      0.0
# min          10.0       1.0     1.0    11.0    10.0                      5.0
# 25%          33.0       3.0     6.0   124.0   118.0                      5.0
# 50%          55.0       5.0    12.0   254.0   242.0                      5.0
# 75%          78.0       8.0    22.0   471.0   449.0                      5.0
# max         100.0      10.0    50.0  1043.0   993.0                      5.0
#
#        gross income  Rating
# count        1000.0  1000.0
# mean           15.0     7.0
# std            12.0     2.0
# min             1.0     4.0
# 25%             6.0     6.0
# 50%            12.0     7.0
# 75%            22.0     8.0
# max            50.0    10.0

# %%
# Count the number of unique cities
num_unique_cities = data['City'].nunique()
# Print the number of unique cities
print("Number of unique cities:", num_unique_cities)
unique_cities = data['City'].unique()
unique_cities
# Out:
# Number of unique cities: 3
# array(['Yangon', 'Naypyitaw', 'Mandalay'], dtype=object)

# %%
product=data['Product line'] .unique()
product
# Out:
# array(['Health and beauty', 'Electronic accessories',
#        'Home and lifestyle', 'Sports and travel', 'Food and beverages',
#        'Fashion accessories'], dtype=object)

# %%
payment=data['Payment'].unique()
payment
# Out:
# array(['Ewallet', 'Cash', 'Credit card'], dtype=object)

# %%
branch=data['Branch'].unique()
branch
# Out:
# array(['A', 'C', 'B'], dtype=object)

# %%
# In which city is each branch?

branch_city_mapping = data.groupby('Branch')['City'].unique()
branch_city_mapping
# Out:
# Branch
# A       [Yangon]
# B     [Mandalay]
# C    [Naypyitaw]
# Name: City, dtype: object

# %%
# What is the most common payment method?
# Count the occurrences of each payment method
payment_counts = data["Payment"].value_counts()

# Get the most common payment method
most_common_payment = payment_counts.idxmax()

# Print the result
print("The most common payment method is:", most_common_payment)
# Out:
# The most common payment method is: Ewallet

# %%
# Plot the payment method frequencies

payment_counts = data["Payment"].value_counts()

plt.bar(payment_counts.index, payment_counts.values)
plt.xlabel("Payment Method")
plt.ylabel("Frequency")
plt.title("Payment Method Frequencies")
plt.show()

# %%
#  What is the most selling product line?

# Group the data by product line and calculate the sum of quantities sold
product_line_sales = data.groupby('Product line')['Quantity'].sum()

# Find the product line with the highest quantity sold
most_selling_product_line = product_line_sales.idxmax()

print("The most selling product line is:", most_selling_product_line)
# Out:
# The most selling product line is: Electronic accessories

# %%
fig= plt.figure(figsize=(10, 6))
product_line_sales.plot(kind='bar')
plt.title('Total Quantity Sold by Product Line')
plt.xlabel('Product Line')
plt.ylabel('Total Quantity Sold')
plt.xticks(rotation=45)
fig.tight_layout()
fig.savefig("a.png")
plt.show()

# %%
#  What is the total revenue by month?
# Convert the "Date" column to datetime format
data['Date'] = pd.to_datetime(data['Date'])

# Extract the month from the "Date" column
data['Month'] = data['Date'].dt.month

# Calculate the total revenue by month
revenue_by_month = data.groupby('Month')['Total'].sum()

print(revenue_by_month)
# Out:
# Month
# 1    116291.868
# 2     97219.374
# 3    109455.507
# Name: Total, dtype: float64

# %%
fig= plt.figure(figsize=(10, 6))
revenue_by_month.plot(kind='bar')
plt.title('Total Revenue by Month')
plt.xlabel('Month')
plt.ylabel('Total Revenue')
plt.xticks(rotation=45)
fig.savefig("b.png")
plt.show()

# %%
# What month had the largest COGS?
data['Date'] = pd.to_datetime(data['Date'])

# Extract the month from the "Date" column
data['Month'] = data['Date'].dt.month

# Calculate the total revenue by month
large_CGOS_month = data.groupby('Month')['cogs'].sum()

print(large_CGOS_month)
# Out:
# Month
# 1    110754.16
# 2     92589.88
# 3    104243.34
# Name: cogs, dtype: float64

# %%
#plot month with highest larget COGS
fig= plt.figure(figsize=(10, 6))
large_CGOS_month.plot(kind='bar')
plt.title('Largest COGS by Month')
plt.xlabel('Month')
plt.ylabel('COGS')
plt.xticks(rotation=45)
fig.savefig("c.png")
plt.show()

# %%
# What product line had the largest revenue?
What is the city with the largest revenue?
# Calculate the revenue for each product line
data['Revenue'] = data['Quantity'] * data['Unit price']

# Group the data by product line and calculate the sum of revenue
product_line_revenue = data.groupby('Product line')['Revenue'].sum()

# Find the product line with the largest revenue
largest_revenue_product_line = product_line_revenue.idxmax()

print("The product line with the largest revenue is:", largest_revenue_product_line)
# Out:
# The product line with the largest revenue is: Food and beverages

# %%
# Plotting the bar chart
plt.figure(figsize=(10, 6))
product_line_revenue.plot(kind='bar')
plt.title('Total Revenue by Product Line')
plt.xlabel('Product Line')
plt.ylabel('Total Revenue')
plt.xticks(rotation=45)
plt.show()

# %%
# What is the city with the largest revenue?

# Calculate the revenue for each product line
data['Revenue'] = data['Quantity'] * data['Unit price']

# Group the data by product line and calculate the sum of revenue
city_high_revenue = data.groupby('City')['Revenue'].sum()

city_high_revenue_index = city_high_revenue.idxmax()

print("The city with the largest revenue is:", city_high_revenue_index)
# Out:
# The city with the largest revenue is: Naypyitaw

# %%
# Plotting the bar chart
plt.figure(figsize=(10, 6))
city_high_revenue.plot(kind='bar')
plt.title('Largest Revenue by City')
plt.xlabel('City')
plt.ylabel('Total Revenue')
plt.xticks(rotation=45)
plt.show()

# %%
# What product line had the largest VAT?

product_line_vat= data.groupby('Product line')['Tax 5%'].sum()

largest_product_line_vat= product_line_vat.idxmax()
print("The product line with the largest VAT is:", largest_product_line_vat)
# Out:
# The product line with the largest VAT is: Food and beverages

# %%
# Plotting the bar chart
plt.figure(figsize=(10, 6))
product_line_vat.plot(kind='bar')
plt.title('Largest VAT by product Line')
plt.xlabel('Product Line')
plt.ylabel('VAT')
plt.xticks(rotation=45)
plt.show()

# %%
#  Fetch each product line and add a column to those product line showing "Good", "Bad". Good if its greater than average sales
# Calculate the average sales. 

average_sales = data['Total'].mean()

# Add a new column 'Sales Status' to indicate whether sales are 'Good' or 'Bad'
data['Sales Status'] = data['Total'].apply(lambda x: 'Good' if x > average_sales else 'Bad')

# Display the updated DataFrame
print(data)
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# 2        Home and lifestyle       46.33         7  16.2155   340.5255
# 3         Health and beauty       58.22         8  23.2880   489.0480
# 4         Sports and travel       86.31         7  30.2085   634.3785
# ..                      ...         ...       ...      ...        ...
# 995       Health and beauty       40.35         1   2.0175    42.3675
# 996      Home and lifestyle       97.38        10  48.6900  1022.4900
# 997      Food and beverages       31.84         1   1.5920    33.4320
# 998      Home and lifestyle       65.82         1   3.2910    69.1110
# 999     Fashion accessories       88.34         7  30.9190   649.2990
#
#           Date      Time      Payment    cogs  gross margin percentage  \
# 0   2019-01-05  13:08:00      Ewallet  522.83                 4.761905
# 1   2019-03-08  10:29:00         Cash   76.40                 4.761905
# 2   2019-03-03  13:23:00  Credit card  324.31                 4.761905
# 3   2019-01-27  20:33:00      Ewallet  465.76                 4.761905
# 4   2019-02-08  10:37:00      Ewallet  604.17                 4.761905
# ..         ...       ...          ...     ...                      ...
# 995 2019-01-29  13:46:00      Ewallet   40.35                 4.761905
# 996 2019-03-02  17:16:00      Ewallet  973.80                 4.761905
# 997 2019-02-09  13:22:00         Cash   31.84                 4.761905
# 998 2019-02-22  15:33:00         Cash   65.82                 4.761905
# 999 2019-02-18  13:28:00         Cash  618.38                 4.761905
#
#      gross income  Rating  Month  Revenue Sales Status
# 0         26.1415     9.1      1   522.83         Good
# 1          3.8200     9.6      3    76.40          Bad
# 2         16.2155     7.4      3   324.31         Good
# 3         23.2880     8.4      1   465.76         Good
# 4         30.2085     5.3      2   604.17         Good
# ..            ...     ...    ...      ...          ...
# 995        2.0175     6.2      1    40.35          Bad
# 996       48.6900     4.4      3   973.80         Good
# 997        1.5920     7.7      2    31.84          Bad
# 998        3.2910     4.1      2    65.82          Bad
# 999       30.9190     6.6      2   618.38         Good
#
# [1000 rows x 20 columns]

# %%
data.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715 2019-01-05
# 1  Electronic accessories       15.28         5   3.8200   80.2200 2019-03-08
# 2      Home and lifestyle       46.33         7  16.2155  340.5255 2019-03-03
# 3       Health and beauty       58.22         8  23.2880  489.0480 2019-01-27
# 4       Sports and travel       86.31         7  30.2085  634.3785 2019-02-08
#
#        Time      Payment    cogs  gross margin percentage  gross income  \
# 0  13:08:00      Ewallet  522.83                 4.761905       26.1415
# 1  10:29:00         Cash   76.40                 4.761905        3.8200
# 2  13:23:00  Credit card  324.31                 4.761905       16.2155
# 3  20:33:00      Ewallet  465.76                 4.761905       23.2880
# 4  10:37:00      Ewallet  604.17                 4.761905       30.2085
#
#    Rating  Month  Revenue Sales Status
# 0     9.1      1   522.83         Good
# 1     9.6      3    76.40          Bad
# 2     7.4      3   324.31         Good
# 3     8.4      1   465.76         Good
# 4     5.3      2   604.17         Good

# %%
# Which branch sold more products than average product sold?

# Calculate the average number of products sold
average_products_sold = data['Quantity'].mean()

# Filter the DataFrame to include branches with sales greater than the average
branches_above_average = data[data['Quantity'] > average_products_sold]['Branch'].unique()

# Display the branches that sold more products than the average
print("Branches with sales above average:")
for branch in branches_above_average:
    print(branch)
# Out:
# Branches with sales above average:
# A
# C
# B

# %%
# Plotting the bar graph
branches_above_average = data[data['Quantity'] > average_products_sold]['Branch'].value_counts()
plt.bar(branches_above_average.index, branches_above_average.values)
plt.xlabel('Branch')
plt.ylabel('Number of Products Sold')
plt.title('Branches with Sales Above Average')
plt.show()

# %%
# What is the most common product line by gender?

grouped_data = data.groupby(['Gender', 'Product line']).size().reset_index(name='Count')

# Find the most common product line for each gender
most_common_product_line = grouped_data.groupby('Gender')['Count'].idxmax()
most_common_product_line_data = grouped_data.loc[most_common_product_line]

# Display the most common product line for each gender
print(most_common_product_line_data[['Gender', 'Product line']])
# Out:
#    Gender         Product line
# 1  Female  Fashion accessories
# 9    Male    Health and beauty

# %%
# Plotting the bar graph
plt.bar(most_common_product_line_data['Gender'], most_common_product_line_data['Count'])
plt.xlabel('Gender')
plt.ylabel('Count')
plt.title('Most Common Product Line by Gender')
plt.show()
